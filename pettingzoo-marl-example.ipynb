# %%
from pettingzoo.butterfly import knights_archers_zombies_v10
env = knights_archers_zombies_v10.env(render_mode="rgb_array")
env.reset(seed=42)

for agent in env.agent_iter():
    observation, reward, termination, truncation, info = env.last()

    if termination or truncation:
        action = None
    else:
        # this is where you would insert your policy
        action = env.action_space(agent).sample()

    env.step(action)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 14
#      10 else:
#      11     # this is where you would insert your policy
#      12     action = env.action_space(agent).sample()
# ---> 14 env.step(action)
#
# File ~/RL-examples/venv/lib/python3.10/site-packages/pettingzoo/utils/wrappers/order_enforcing.py:70, in OrderEnforcingWrapper.step(self, action)
#      68 else:
#      69     self._has_updated = True
# ---> 70     super().step(action)
#
# File ~/RL-examples/venv/lib/python3.10/site-packages/pettingzoo/utils/wrappers/base.py:47, in BaseWrapper.step(self, action)
#      46 def step(self, action: ActionType) -> None:
# ---> 47     self.env.step(action)
#
# File ~/RL-examples/venv/lib/python3.10/site-packages/pettingzoo/utils/wrappers/assert_out_of_bounds.py:26, in AssertOutOfBoundsWrapper.step(self, action)
#      16 def step(self, action: ActionType) -> None:
#      17     assert (
#      18         action is None
#      19         and (
#    (...)
#      24         action
#      25     ), "action is not in action space"
# ---> 26     super().step(action)
#
# File ~/RL-examples/venv/lib/python3.10/site-packages/pettingzoo/utils/wrappers/base.py:47, in BaseWrapper.step(self, action)
#      46 def step(self, action: ActionType) -> None:
# ---> 47     self.env.step(action)
#
# File ~/RL-examples/venv/lib/python3.10/site-packages/pettingzoo/butterfly/knights_archers_zombies/knights_archers_zombies.py:779, in raw_env.step(self, action)
#     776 self._deads_step_first()
#     778 if self.render_mode == "human":
# --> 779     self.render()
#
# File ~/RL-examples/venv/lib/python3.10/site-packages/pettingzoo/butterfly/knights_archers_zombies/knights_archers_zombies.py:821, in raw_env.render(self)
#     819 if self.render_mode == "human":
#     820     pygame.display.flip()
# --> 821     self.clock.tick(self.metadata["render_fps"])
#     822 return (
#     823     np.transpose(observation, axes=(1, 0, 2))
#     824     if self.render_mode == "rgb_array"
#     825     else None
#     826 )
#
# KeyboardInterrupt:

# %%
from pettingzoo.butterfly import pistonball_v6
parallel_env = pistonball_v6.parallel_env(render_mode="human")
observations, infos = parallel_env.reset(seed=42)

while parallel_env.agents:
    # this is where you would insert your policy
    actions = {agent: parallel_env.action_space(agent).sample() for agent in parallel_env.agents}

    observations, rewards, terminations, truncations, infos = parallel_env.step(actions)
parallel_env.close()

# %%
from pettingzoo.atari import space_invaders_v2

env = space_invaders_v2.env(render_mode="human")
env.reset(seed=42)

for agent in env.agent_iter():
    observation, reward, termination, truncation, info = env.last()

    if termination or truncation:
        action = None
    else:
        action = env.action_space(agent).sample() # this is where you would insert your policy

    env.step(action)
env.close()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[6], line 3
#       1 from pettingzoo.atari import space_invaders_v2
# ----> 3 env = space_invaders_v2.env(render_mode="human")
#       4 env.reset(seed=42)
#       6 for agent in env.agent_iter():
#
# File ~/RL-examples/venv/lib/python3.10/site-packages/pettingzoo/atari/base_atari_env.py:25, in base_env_wrapper_fn.<locals>.env_fn(**kwargs)
#      24 def env_fn(**kwargs):
# ---> 25     env = raw_env_fn(**kwargs)
#      26     env = wrappers.AssertOutOfBoundsWrapper(env)
#      27     env = wrappers.OrderEnforcingWrapper(env)
#
# File ~/RL-examples/venv/lib/python3.10/site-packages/pettingzoo/atari/space_invaders/space_invaders.py:109, in raw_env(alternating_control, moving_shields, zigzaging_bombs, fast_bomb, invisible_invaders, **kwargs)
#     107 version_num = parent_file[0].split("_")[-1].split(".")[0]
#     108 name = name + "_" + version_num
# --> 109 return BaseAtariEnv(
#     110     game="space_invaders", num_players=2, mode_num=mode, env_name=name, **kwargs
#     111 )
#
# File ~/RL-examples/venv/lib/python3.10/site-packages/pettingzoo/atari/base_atari_env.py:34, in BaseAtariEnv(**kwargs)
#      33 def BaseAtariEnv(**kwargs):
# ---> 34     return parallel_to_aec_wrapper(ParallelAtariEnv(**kwargs))
#
# File ~/RL-examples/venv/lib/python3.10/site-packages/pettingzoo/atari/base_atari_env.py:109, in ParallelAtariEnv.__init__(self, game, num_players, mode_num, seed, obs_type, full_action_space, env_name, max_cycles, render_mode, auto_rom_install_path)
#     106     final = start / "ROM" / game / f"{game}.bin"
#     108 if not final.exists():
# --> 109     raise OSError(
#     110         f"rom {game} is not installed. Please install roms using AutoROM tool (https://github.com/Farama-Foundation/AutoROM) "
#     111         "or specify and double-check the path to your Atari rom using the `rom_path` argument."
#     112     )
#     114 self.rom_path = str(final)
#     115 self.ale.loadROM(self.rom_path)
#
# OSError: rom space_invaders is not installed. Please install roms using AutoROM tool (https://github.com/Farama-Foundation/AutoROM) or specify and double-check the path to your Atari rom using the `rom_path` argument.
